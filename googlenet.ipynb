# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd drive/My\ Drive/CS4487_Final_Project
# Out:
# /content/drive/My Drive/veljko2

# %%
# !python3 main.py
# Out:
# ==> Preparing data..
# ...
# 170500096it [00:04, 39854276.44it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# ==> Building model..
#
# Epoch: 0
#  [================================================================>]  Step: 663ms | Tot: 24s293ms | Loss: 2.351 | Acc: 25.480% (12740/50000) 391/391
#  [================================================================>]  Step: 13ms | Tot: 2s401ms | Loss: 1.654 | Acc: 39.220% (3922/10000) 100/100
# Saving..
#
# Epoch: 1
#  [================================================================>]  Step: 35ms | Tot: 23s424ms | Loss: 1.612 | Acc: 40.586% (20293/50000) 391/391
#  [================================================================>]  Step: 13ms | Tot: 2s274ms | Loss: 1.464 | Acc: 46.880% (4688/10000) 100/100
# Saving..
#
# Epoch: 2
#  [================================================================>]  Step: 34ms | Tot: 22s944ms | Loss: 1.461 | Acc: 46.500% (23250/50000) 391/391
# ...

# %%
# !python3 main.py --resume --lr=0.01
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
# ==> Resuming from checkpoint..
#
# Epoch: 40
#  [================================================================>]  Step: 650ms | Tot: 22s196ms | Loss: 0.552 | Acc: 80.930% (40465/50000) 391/391
#  [================================================================>]  Step: 14ms | Tot: 2s179ms | Loss: 0.501 | Acc: 82.680% (8268/10000) 100/100
# Saving..
#
# Epoch: 41
#  [================================================================>]  Step: 42ms | Tot: 21s683ms | Loss: 0.489 | Acc: 83.046% (41523/50000) 391/391
#  [================================================================>]  Step: 12ms | Tot: 2s123ms | Loss: 0.476 | Acc: 83.360% (8336/10000) 100/100
# Saving..
#
# Epoch: 42
#  [================================================================>]  Step: 34ms | Tot: 21s963ms | Loss: 0.462 | Acc: 84.016% (42008/50000) 391/391
# ...

# %%
# !python3 main.py --resume --lr=0.001
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
# ==> Resuming from checkpoint..
#
# Epoch: 184
#  [================================================================>]  Step: 670ms | Tot: 22s423ms | Loss: 0.189 | Acc: 93.600% (46800/50000) 391/391
#  [================================================================>]  Step: 13ms | Tot: 2s173ms | Loss: 0.308 | Acc: 89.720% (8972/10000) 100/100
# Saving..
#
# Epoch: 185
#  [================================================================>]  Step: 35ms | Tot: 21s513ms | Loss: 0.158 | Acc: 94.640% (47320/50000) 391/391
#  [================================================================>]  Step: 13ms | Tot: 2s129ms | Loss: 0.302 | Acc: 90.120% (9012/10000) 100/100
# Saving..
#
# Epoch: 186
#  [================================================================>]  Step: 35ms | Tot: 21s541ms | Loss: 0.147 | Acc: 95.050% (47525/50000) 391/391
# ...

# %%
# !python3 main.py --resume --lr=0.0001
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
# ==> Resuming from checkpoint..
#
# Epoch: 194
#  [================================================================>]  Step: 652ms | Tot: 22s491ms | Loss: 0.104 | Acc: 96.346% (48173/50000) 391/391
#  [================================================================>]  Step: 12ms | Tot: 2s149ms | Loss: 0.307 | Acc: 90.560% (9056/10000) 100/100
#
# Epoch: 195
#  [================================================================>]  Step: 36ms | Tot: 22s62ms | Loss: 0.100 | Acc: 96.636% (48318/50000) 391/391
#  [================================================================>]  Step: 15ms | Tot: 2s165ms | Loss: 0.306 | Acc: 90.610% (9061/10000) 100/100
#
# Epoch: 196
#  [================================================================>]  Step: 35ms | Tot: 21s688ms | Loss: 0.100 | Acc: 96.584% (48292/50000) 391/391
# ...
