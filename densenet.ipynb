# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd drive/My\ Drive/python_project
# Out:
# /content/drive/My Drive/python_project

# %%
# !python3 main.py
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
#
# Epoch: 0
#  [================================================================>]  Step: 665ms | Tot: 22s355ms | Loss: 2.424 | Acc: 24.104% (12052/50000) 391/391
#  [================================================================>]  Step: 13ms | Tot: 2s122ms | Loss: 1.787 | Acc: 34.220% (3422/10000) 100/100
# Saving..
#
# Epoch: 1
#  [================================================================>]  Step: 35ms | Tot: 21s838ms | Loss: 1.607 | Acc: 40.710% (20355/50000) 391/391
#  [================================================================>]  Step: 12ms | Tot: 2s134ms | Loss: 1.468 | Acc: 45.440% (4544/10000) 100/100
# Saving..
#
# Epoch: 2
#  [================================================================>]  Step: 35ms | Tot: 21s417ms | Loss: 1.409 | Acc: 48.822% (24411/50000) 391/391
# ...

# %%
# !python3 main.py --resume --lr=0.01
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
# ==> Resuming from checkpoint..
#
# Epoch: 28
#  [================================================================>]  Step: 649ms | Tot: 21s757ms | Loss: 0.581 | Acc: 79.894% (39947/50000) 391/391
#  [================================================================>]  Step: 12ms | Tot: 2s73ms | Loss: 0.535 | Acc: 81.390% (8139/10000) 100/100
# Saving..
#
# Epoch: 29
#  [================================================================>]  Step: 36ms | Tot: 21s578ms | Loss: 0.510 | Acc: 82.076% (41038/50000) 391/391
#  [================================================================>]  Step: 13ms | Tot: 2s111ms | Loss: 0.504 | Acc: 82.700% (8270/10000) 100/100
# Saving..
#
# Epoch: 30
#  [================================================================>]  Step: 34ms | Tot: 21s369ms | Loss: 0.483 | Acc: 83.278% (41639/50000) 391/391
# ...

# %%
# !python3 main.py --resume --lr=0.001
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
# ==> Resuming from checkpoint..
#
# Epoch: 275
#  [================================================================>]  Step: 660ms | Tot: 21s691ms | Loss: 0.132 | Acc: 95.442% (47721/50000) 391/391
#  [================================================================>]  Step: 13ms | Tot: 2s6ms | Loss: 0.318 | Acc: 90.100% (9010/10000) 100/100
# Saving..
#
# Epoch: 276
#  [================================================================>]  Step: 34ms | Tot: 21s14ms | Loss: 0.103 | Acc: 96.634% (48317/50000) 391/391
#  [================================================================>]  Step: 13ms | Tot: 2s111ms | Loss: 0.316 | Acc: 90.110% (9011/10000) 100/100
# Saving..
#
# Epoch: 277
#  [================================================================>]  Step: 36ms | Tot: 21s54ms | Loss: 0.090 | Acc: 97.086% (48543/50000) 391/391
# ...
